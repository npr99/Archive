# %% [markdown]
# <a href="https://colab.research.google.com/github/npr99/Archive/blob/master/IN_CORE_2ev1_Lumberton_AddStructureID.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Add Structure ID to Address Point and Building Inventory
# The current version of IN-CORE uses Structure ID to connect the Address Point and Building Inventory. The variable structure ID needs to be non-missing in both files.
#
# Current solution is to use GUID as the Structure ID and then fill in missing structure ids using the Block ID in the address point inventory.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import math as math
import numpy as np
import geopandas as gpd
import pandas as pd
import shapely
import descartes

import folium as fm # folium has more dynamic maps - but requires internet connection

import os # For saving output to path
# Out:
# C:\Users\nathanael99\AppData\Roaming\Python\Python37\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.4) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
# Display versions being used - important information for replication
import sys
print("Python Version     ", sys.version)
print("numpy version:     ", np.__version__)
print("geopandas version: ", gpd.__version__)
print("pandas version:    ", pd.__version__)
print("shapely version:   ", shapely.__version__)
# print("descartes version:   ", descartes.__version__)  1.1.0
print("folium version:    ", fm.__version__)
# Out:
# Python Version      3.7.10 | packaged by conda-forge | (default, Feb 19 2021, 15:37:01) [MSC v.1916 64 bit (AMD64)]
# numpy version:      1.20.2
# geopandas version:  0.9.0
# pandas version:     0.24.2
# shapely version:    1.7.1
# folium version:     0.9.1

# %%
# Store Program Name for output files to have the same name
programname = "IN-CORE_2ev1_Lumberton_AddStructureID_2021-04-27"
# Make directory to save output
if not os.path.exists(programname):
    os.mkdir(programname)

# %% [markdown]
# ## Setup access to IN-CORE
# https://incore.ncsa.illinois.edu/

# %%
from pyincore import IncoreClient, Dataset, FragilityService, MappingSet, DataService
from pyincore_viz.geoutil import GeoUtil as viz

# %%
client = IncoreClient()
# IN-CORE chaches files on the local machine, it might be necessary to clear the memory
#client.clear_cache()
# Out:
# Connection successful to IN-CORE services. pyIncore version detected: 0.9.2

# %%
# create data_service object for loading files
data_service = DataService(client)

# %% [markdown]
# ## Read in Building Inventory
# The building inventory provide basic understanding of where address points can be located.

# %%
# Lumberton, NC Building inventory
bldg_inv_id = "6036c2a9e379f22e1658d451" 
# load building inventory
bldg_inv = Dataset.from_data_service(bldg_inv_id, data_service)
filename = bldg_inv.get_file_path('shp')
print("The IN-CORE Dataservice has saved the Building Inventory on your local machine: "+filename)
# Out:
# Dataset already exists locally. Reading from local cached zip.
# Unzipped folder found in the local cache. Reading from it...
# The IN-CORE Dataservice has saved the Building Inventory on your local machine: C:\Users\nathanael99\.incore\cache_data\6036c2a9e379f22e1658d451\lumberton-bldg-v7\lumberton-bldg-v7.shp

# %%
bldg_inv_gdf = gpd.read_file(filename)
bldg_inv_gdf.crs = {'init': 'epsg:4326'}
bldg_inv_gdf.head()
# Out:
#    ffe_elev  archetype       parid struct_typ  no_stories a_stories b_stories  \
# 0   0.00000          0        None       None           0      None      None
# 1   0.00000          8        None       None           0      None      None
# 2   0.00000          8        None       None           0      None      None
# 3  36.88080          0        None       None           1      None      None
# 4  31.78537          2  3715560148       None           1      None      None
#
#   bsmt_type  sq_foot  gsq_foot  ... strctid appr_bldg appr_land appr_tot  \
# 0      None       20        20  ...    None      None      None     None
# 1      None        0         0  ...    None      None      None     None
# 2      None        0         0  ...    None      None      None     None
# 3      None        0         0  ...    None      None      None     None
# 4      None     1128      1128  ...    None      None      None     None
#
#    year_built lhsm_elev g_elev                                  guid  \
# 0         NaN      None   None  2d32aeff-7b75-47e6-b7a5-4f4adca4b021
# 1         NaN      None   None  78e8556b-15b3-45e9-a72d-dba53a188b8d
# 2         NaN      None   None  6b481629-e0c6-48f6-b1ce-d57f65d35cb6
# 3         NaN      None   None  a6875194-ad6b-4061-9855-fe8a8b0f5ba6
# 4      1988.0      None   None  3928ae4d-4450-427f-8fc3-2294d36879f8
#
#   age_group                    geometry
# 0       NaN  POINT (-78.99633 34.65436)
# 1       NaN  POINT (-79.01852 34.64057)
# 2       NaN  POINT (-79.02847 34.60277)
# 3       NaN  POINT (-79.05967 34.61999)
# 4       3.0  POINT (-78.94659 34.55213)
#
# [5 rows x 34 columns]

# %%
# lok at Archtypes
#pd.crosstab(index=bldg_inv_gdf.archetype, columns="count")
bldg_inv_gdf.groupby(['archetype']).count()
# Out:
#            ffe_elev  parid  struct_typ  no_stories  a_stories  b_stories  \
# archetype
# 0                25     23           0          25          0          0
# 1              6070   6070           0        6070          0          0
# 2             10273  10273           0       10273          0          0
# 3               249    249           0         249          0          0
# 4              1391   1391           0        1391          0          0
# 5              1060   1060           0        1060          0          0
# 6                 9      9           0           9          0          0
# 7                10     10           0          10          0          0
# 8                14     12           0          14          0          0
# 9               149    149           0         149          0          0
# 10               84     84           0          84          0          0
# 11                4      4           0           4          0          0
# 12               23     23           0          23          0          0
# 13              195    195           0         195          0          0
# 14              162    162           0         162          0          0
# 15              373    373           0         373          0          0
#
#            bsmt_type  sq_foot  gsq_foot  occ_type  ...  strctid  appr_bldg  \
# archetype                                          ...
# 0                  0       25        25        24  ...        0          0
# 1                  0     6070      6070      6070  ...        0          0
# 2                  0    10273     10273     10273  ...        0          0
# 3                  0      249       249       249  ...        0          0
# 4                  0     1391      1391      1391  ...        0          0
# 5                  0     1060      1060      1060  ...        0          0
# 6                  0        9         9         9  ...        0          0
# 7                  0       10        10        10  ...        0          0
# 8                  0       14        14        12  ...        0          0
# 9                  0      149       149       149  ...        0          0
# 10                 0       84        84        84  ...        0          0
# 11                 0        4         4         4  ...        0          0
# 12                 0       23        23        23  ...        0          0
# 13                 0      195       195       195  ...        0          0
# 14                 0      162       162       162  ...        0          0
# 15                 0      373       373       373  ...        0          0
#
#            appr_land  appr_tot  year_built  lhsm_elev  g_elev   guid  \
# archetype
# 0                  0         0          23          0       0     25
# 1                  0         0        6061          0       0   6070
# 2                  0         0       10258          0       0  10273
# 3                  0         0         249          0       0    249
# 4                  0         0        1387          0       0   1391
# 5                  0         0        1060          0       0   1060
# 6                  0         0           9          0       0      9
# 7                  0         0          10          0       0     10
# 8                  0         0          12          0       0     14
# 9                  0         0         149          0       0    149
# 10                 0         0          84          0       0     84
# 11                 0         0           4          0       0      4
# 12                 0         0          23          0       0     23
# 13                 0         0         195          0       0    195
# 14                 0         0         162          0       0    162
# 15                 0         0         373          0       0    373
#
#            age_group  geometry
# archetype
# 0                 23        25
# 1               6061      6070
# 2              10258     10273
# 3                249       249
# 4               1387      1391
# 5               1060      1060
# 6                  9         9
# 7                 10        10
# 8                 12        14
# 9                149       149
# 10                84        84
# 11                 4         4
# 12                23        23
# 13               195       195
# 14               162       162
# 15               373       373
#
# [16 rows x 33 columns]

# %%
# iterating the columns
for col in bldg_inv_gdf.columns:
    print(col)
# Out:
# ffe_elev
# archetype
# parid
# struct_typ
# no_stories
# a_stories
# b_stories
# bsmt_type
# sq_foot
# gsq_foot
# occ_type
# occ_detail
# major_occ
# broad_occ
# repl_cst
# str_cst
# nstra_cst
# nstrd_cst
# dgn_lvl
# cont_val
# efacility
# dwell_unit
# str_typ2
# occ_typ2
# strctid
# appr_bldg
# appr_land
# appr_tot
# year_built
# lhsm_elev
# g_elev
# guid
# age_group
# geometry

# %%
bldg_inv_gdf.strctid.describe()
# Out:
# count     0
# unique    0
# Name: strctid, dtype: int64

# %%
# Make Strctid = GUID
bldg_inv_gdf.loc[(bldg_inv_gdf['guid'].notna()),
                            'strctid'] = bldg_inv_gdf.apply(lambda x: "ST"+ str(x['guid']).zfill(36), axis=1)
# Confirm Primary Key is Unique and Non-Missing
bldg_inv_gdf[['strctid']].head(10)
# Out:
#                                   strctid
# 0  ST2d32aeff-7b75-47e6-b7a5-4f4adca4b021
# 1  ST78e8556b-15b3-45e9-a72d-dba53a188b8d
# 2  ST6b481629-e0c6-48f6-b1ce-d57f65d35cb6
# 3  STa6875194-ad6b-4061-9855-fe8a8b0f5ba6
# 4  ST3928ae4d-4450-427f-8fc3-2294d36879f8
# 5  ST00624632-6917-4ffc-a597-bcb30eda00c8
# 6  STb234aa50-36bb-40e1-b470-146fe5a06111
# 7  ST33d858f3-9ebc-4065-8688-af69fb1026ad
# 8  ST57f6075f-69ba-4033-af32-fae6467e6f21
# 9  ST89003bde-787c-486a-ba67-eb2f1a5efe3f

# %%
# Make sure structure id is non-missing
bldg_inv_gdf.strctid.isna().sum()
# Out:
# 0

# %%
# Move Primary Key Column Building ID to first Column
cols = ['strctid']  + [col for col in bldg_inv_gdf if col != 'strctid']
bldg_inv_gdf = bldg_inv_gdf[cols]
cols = ['guid']  + [col for col in bldg_inv_gdf if col != 'guid']
bldg_inv_gdf = bldg_inv_gdf[cols]
bldg_inv_gdf.head()
# Out:
#                                    guid  \
# 0  2d32aeff-7b75-47e6-b7a5-4f4adca4b021
# 1  78e8556b-15b3-45e9-a72d-dba53a188b8d
# 2  6b481629-e0c6-48f6-b1ce-d57f65d35cb6
# 3  a6875194-ad6b-4061-9855-fe8a8b0f5ba6
# 4  3928ae4d-4450-427f-8fc3-2294d36879f8
#
#                                   strctid  ffe_elev  archetype       parid  \
# 0  ST2d32aeff-7b75-47e6-b7a5-4f4adca4b021   0.00000          0        None
# 1  ST78e8556b-15b3-45e9-a72d-dba53a188b8d   0.00000          8        None
# 2  ST6b481629-e0c6-48f6-b1ce-d57f65d35cb6   0.00000          8        None
# 3  STa6875194-ad6b-4061-9855-fe8a8b0f5ba6  36.88080          0        None
# 4  ST3928ae4d-4450-427f-8fc3-2294d36879f8  31.78537          2  3715560148
#
#   struct_typ  no_stories a_stories b_stories bsmt_type  ...  str_typ2  \
# 0       None           0      None      None      None  ...      None
# 1       None           0      None      None      None  ...      None
# 2       None           0      None      None      None  ...      None
# 3       None           1      None      None      None  ...      None
# 4       None           1      None      None      None  ...      None
#
#    occ_typ2 appr_bldg appr_land appr_tot year_built  lhsm_elev g_elev  \
# 0      None      None      None     None        NaN       None   None
# 1      None      None      None     None        NaN       None   None
# 2      None      None      None     None        NaN       None   None
# 3      None      None      None     None        NaN       None   None
# 4      None      None      None     None     1988.0       None   None
#
#   age_group                    geometry
# 0       NaN  POINT (-78.99633 34.65436)
# 1       NaN  POINT (-79.01852 34.64057)
# 2       NaN  POINT (-79.02847 34.60277)
# 3       NaN  POINT (-79.05967 34.61999)
# 4       3.0  POINT (-78.94659 34.55213)
#
# [5 rows x 34 columns]

# %% [markdown]
# # Clean mereged data to match
#
# The latest Building Inventory of a shape file is of version 6, we use the type
# ergo:buildingInventoryVer6
#
# https://opensource.ncsa.illinois.edu/confluence/display/INCORE1/Building+Inventory+Datatype+Schema
#
# Variables to include
# v6
# guid
#
# strctid
#
# struct_typ
#
# archetype
#
# occ_type
#
# appr_bldg
#
# sq_foot
#
# dwell_unit
#
# no_stories
#
# cont_val
#
# str_typ2
#
# efacility
#
# parid
#
# year_built
#
# a_stories
#
# b_stories
#
# bsmt_type
#
# gsq_foot
#
# occ_detail
#
# major_occ
#
# broad_occ
#
# repl_cst
#
# str_cst
#
# nstra_cst
#
# nstrd_cst
#
# dgn_lvl
#
# occ_typ2
#
# appr_land
#
# appr_tot

# %%
# create list of all required ergo:buildingInventoryVer6 columns
incore_columns = ['guid',
                  'strctid',
                  'struct_typ', 
                  'archetype', 
                  'occ_type', 
                  'appr_bldg', 
                  'sq_foot', 
                  'dwell_unit', 
                  'no_stories', 
                  'cont_val', 
                  'str_typ2', 
                  'efacility', 
                  'parid', 
                  'year_built', 
                  'a_stories', 
                  'b_stories', 
                  'bsmt_type', 
                  'gsq_foot', 
                  'occ_detail', 
                  'major_occ', 
                  'broad_occ', 
                  'repl_cst', 
                  'str_cst', 
                  'nstra_cst', 
                  'nstrd_cst', 
                  'dgn_lvl', 
                  'occ_typ2', 
                  'appr_land', 
                  'appr_tot']
incore_columns_df = pd.Series(incore_columns,name='varname')
incore_columns_df = pd.DataFrame(incore_columns,columns =['varname']).sort_values(by=['varname'])
incore_columns_df.head()
# Out:
#       varname
# 14  a_stories
# 5   appr_bldg
# 27  appr_land
# 28   appr_tot
# 3   archetype

# %%
columnlist = pd.DataFrame(bldg_inv_gdf.columns,columns =['varname']).sort_values(by=['varname'])
columnlist.head()
# Out:
#       varname
# 7   a_stories
# 32  age_group
# 26  appr_bldg
# 27  appr_land
# 28   appr_tot

# %%
columnlist_merge = columnlist.merge(incore_columns_df, how='outer', left_on='varname', right_on='varname', indicator = True)
columnlist_merge
# Out:
#        varname     _merge
# 0    a_stories       both
# 1    age_group  left_only
# 2    appr_bldg       both
# 3    appr_land       both
# 4     appr_tot       both
# 5    archetype       both
# 6    b_stories       both
# 7    broad_occ       both
# 8    bsmt_type       both
# 9     cont_val       both
# 10     dgn_lvl       both
# 11  dwell_unit       both
# 12   efacility       both
# 13    ffe_elev  left_only
# 14      g_elev  left_only
# 15    geometry  left_only
# 16    gsq_foot       both
# 17        guid       both
# 18   lhsm_elev  left_only
# 19   major_occ       both
# 20  no_stories       both
# 21   nstra_cst       both
# 22   nstrd_cst       both
# 23  occ_detail       both
# 24    occ_typ2       both
# 25    occ_type       both
# 26       parid       both
# 27    repl_cst       both
# 28     sq_foot       both
# 29     str_cst       both
# 30    str_typ2       both
# 31     strctid       both
# 32  struct_typ       both
# 33  year_built       both

# %%
left_only_cols = columnlist_merge.loc[columnlist_merge['_merge'] == 'left_only']
left_only_cols
# Out:
#       varname     _merge
# 1   age_group  left_only
# 13   ffe_elev  left_only
# 14     g_elev  left_only
# 15   geometry  left_only
# 18  lhsm_elev  left_only

# %% [markdown]
# ### Check the Coordinate Reference System

# %%
type(bldg_inv_gdf.crs)
# Out:
# pyproj.crs.CRS

# %%
bldg_inv_gdf.crs
# Out:
# <Geographic 2D CRS: +init=epsg:4326 +type=crs>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - lon[east]: Longitude (degree)
# - lat[north]: Latitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# ### Save as Shapefile

# %%
savefile = programname+"/"+"IN-CORE_Lumberton_BuildingInventory_2021-04-27.shp"
bldg_inv_gdf.to_file(savefile)
