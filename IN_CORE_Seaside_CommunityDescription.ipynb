# %% [markdown]
# <a href="https://colab.research.google.com/github/npr99/Archive/blob/master/IN_CORE_Seaside_CommunityDescription.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Seaside Testbed - Initial Interdependent Community Description

# %% [markdown]
# <img alt="" src="data:image/png;base64,..." />

# %% [markdown]
# # Basic Conceptual Structure of IN-CORE
# Step 1 in IN-CORE is to establish initial interdepent community description at time 0 and with policy levers and decision combinations set to K (baseline case). The community description includes three parts - the built enviroment, social systems, and economic systems. This notebook helps explore the data currently available in IN-CORE for the Seaside Testbed.
#
# Seaside, OR is a community located on the Pacific Ocean in Northwest Oregon. The city has a high earthquake and tsunami risks.

# %%
import pandas as pd
import geopandas as gpd # For reading in shapefiles
import numpy as np
import sys # For displaying package versions
import os # For managing directories and file paths if drive is mounted

from pyincore import IncoreClient, Dataset, FragilityService, MappingSet, DataService
from pyincore.analyses.buildingdamage.buildingdamage import BuildingDamage

from pyincore_viz.geoutil import GeoUtil as viz
# Out:
# C:\Users\nathanael99\AppData\Roaming\Python\Python37\site-packages\requests\__init__.py:91: RequestsDependencyWarning: urllib3 (1.26.3) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
# Check package versions - good practice for replication
print("Python Version ",sys.version)
print("pandas version: ", pd.__version__)
print("numpy version: ", np.__version__)
# Out:
# Python Version  3.7.10 | packaged by conda-forge | (default, Feb 19 2021, 15:37:01) [MSC v.1916 64 bit (AMD64)]
# pandas version:  0.24.2
# numpy version:  1.20.1

# %%
# Check working directory - good practice for relative path access
os.getcwd()
# Out:
# 'G:\\Shared drives\\HRRC_IN-CORE\\Tasks\\P4.9 Testebeds\\WorkNPR'

# %%
client = IncoreClient()
# IN-CORE chaches files on the local machine, it might be necessary to clear the memory
#client.clear_cache()
# Out:
# Connection successful to IN-CORE services. pyIncore version detected: 0.9.0

# %%
# create data_service object for loading files
data_service = DataService(client)

# %% [markdown]
# ## 1a) Built enviroment: Building Inventory
#
# The building inventory for Joplin consists of...

# %%
# Temporary Seaside, OR Building Inventory v6
building_inv = Dataset.from_file("IN-CORE_Seaside_BuildingInventory_2021-03-19.shp", data_type='ergo:buildingInventoryVer6')

# %%
bldg_inv_gdf = gpd.read_file("IN-CORE_Seaside_BuildingInventory_2021-03-19.shp")
bldg_inv_gdf.head()
# Out:
#   FID_NEW a_stories  appr_bldg b_stories bldg_id broad_occ bsmt_type cont_val  \
# 0    5783      None       2895      None    None      None      None     None
# 1    5782      None      31878      None    None      None      None     None
# 2    5781      None       5743      None    None      None      None     None
# 3    5780      None       9598      None    None      None      None     None
# 4    5779      None       1899      None    None      None      None     None
#
#       dgn_lvl dwell_unit  ... str_prob  str_typ2 struct_typ tract_id  \
# 0  Pre - Code       None  ...     None        W1         W1     None
# 1  Low - Code       None  ...     None        W1         W1     None
# 2  Low - Code       None  ...     None        W1         W1     None
# 3  Low - Code       None  ...     None        W1         W1     None
# 4  Pre - Code       None  ...     None        W1         W1     None
#
#   year_built             strctid           x          y value_matc  \
# 0       1968  41007020933038031S -123.908997  46.014336          0
# 1       1992  41007022416079053S -123.905846  45.997948          0
# 2       1974  41007020933038014S -123.908997  46.014336          0
# 3       1984  41007020933038018S -123.908997  46.014336          0
# 4       1964  41007022789002002S -123.911827  45.997475          0
#
#                       geometry
# 0  POINT (-123.90900 46.01433)
# 1  POINT (-123.90585 45.99795)
# 2  POINT (-123.90900 46.01433)
# 3  POINT (-123.90900 46.01433)
# 4  POINT (-123.91183 45.99747)
#
# [5 rows x 41 columns]

# %%
bldg_inv_gdf.columns
# Out:
# Index(['FID_NEW', 'a_stories', 'appr_bldg', 'b_stories', 'bldg_id',
#        'broad_occ', 'bsmt_type', 'cont_val', 'dgn_lvl', 'dwell_unit',
#        'efacility', 'elev', 'gsq_foot', 'guid', 'major_occ', 'no_stories',
#        'nstra_cst', 'nstrd_cst', 'occ_detail', 'occ_typ2', 'occ_type',
#        'origin', 'parid', 'parid_card', 'period', 'repl_cst', 'rmv_improv',
#        'rmv_land', 'sq_foot', 'stat_class', 'str_cst', 'str_prob', 'str_typ2',
#        'struct_typ', 'tract_id', 'year_built', 'strctid', 'x', 'y',
#        'value_matc', 'geometry'],
#       dtype='object')

# %%
bldg_inv_gdf[['guid','strctid','struct_typ','struct_typ','year_built','occ_type']].head()
# Out:
#                                    guid             strctid struct_typ  \
# 0  fba4c73f-9b1b-4942-b7fb-bc276a4e0a4e  41007020933038031S         W1
# 1  65d6e370-c05b-4b2f-bd17-d914d1d056c7  41007022416079053S         W1
# 2  dad76485-9694-409e-ac7f-c64c7bd5c32c  41007020933038014S         W1
# 3  6f57cfb6-d244-40d5-96f5-03aeddd5e30a  41007020933038018S         W1
# 4  929f1040-6224-409d-b4e3-58946daf3b91  41007022789002002S         W1
#
#   struct_typ  year_built occ_type
# 0         W1        1968     None
# 1         W1        1992     None
# 2         W1        1974     None
# 3         W1        1984     None
# 4         W1        1964     None

# %%
bldg_inv_gdf['strctid'].describe()
# Out:
# count                                     4679
# unique                                    4679
# top       e436df3c-99b6-43f0-8f2b-36ed470c4c6b
# freq                                         1
# Name: strctid, dtype: object

# %%
bldg_inv_gdf[['guid','strctid','struct_typ','year_built','occ_type']].groupby('struct_typ').count()
# Out:
#             guid  strctid  year_built  occ_type
# struct_typ
# RC          1504     1504        1504         0
# W1          2444     2444        2444         0
# W2           731      731         731         0

# %%
map = viz.plot_gdf_map(bldg_inv_gdf,column='struct_typ')
map

# %%
bldg_inv_gdf
# Out:
#      FID_NEW a_stories  appr_bldg b_stories bldg_id broad_occ bsmt_type  \
# 0       5783      None       2895      None    None      None      None
# 1       5782      None      31878      None    None      None      None
# 2       5781      None       5743      None    None      None      None
# 3       5780      None       9598      None    None      None      None
# 4       5779      None       1899      None    None      None      None
# 5       5778      None      11578      None    None      None      None
# 6       5777      None    1619696      None    None      None      None
# 7       5776      None       8211      None    None      None      None
# 8       5774      None       1297      None    None      None      None
# 9       5773      None       8662      None    None      None      None
# 10      5772      None      11820      None    None      None      None
# 11      5771      None      21470      None    None      None      None
# 12      5770      None      18415      None    None      None      None
# 13      5769      None     921153      None    None      None      None
# 14      5768      None      25411      None    None      None      None
# 15      5767      None      46863      None    None      None      None
# 16      5766      None       6090      None    None      None      None
# 24       None       Pre - Code       None  ...     None        W1         W1
# 25       None       Pre - Code       None  ...     None        RC         RC
# 26       None  Moderate - Code       None  ...     None        W1         W1
# 27       None       Low - Code       None  ...     None        W1         W1
# 28       None  Moderate - Code       None  ...     None        W1         W1
# 29       None  Moderate - Code       None  ...     None        W1         W1
# ...       ...              ...        ...  ...      ...       ...        ...
# 4649     None  Moderate - Code       None  ...     None        RC         RC
# 4650     None       Pre - Code       None  ...     None        W1         W1
# 4651     None       Pre - Code       None  ...     None        W2         W2
# 4652     None       Pre - Code       None  ...     None        RC         RC
# 4653     None       Pre - Code       None  ...     None        W1         W1
# 4654     None       Pre - Code       None  ...     None        W1         W1
# 4655     None       Pre - Code       None  ...     None        W1         W1
# 4656     None  Moderate - Code       None  ...     None        RC         RC
# 4657     None  Moderate - Code       None  ...     None        W1         W1
# 4658     None       Pre - Code       None  ...     None        W1         W1
# 4659     None       Pre - Code       None  ...     None        W1         W1
# 4660     None       Low - Code       None  ...     None        W1         W1
# 4661     None      High - Code       None  ...     None        RC         RC
# 4662     None      High - Code       None  ...     None        RC         RC
# 4663     None      High - Code       None  ...     None        RC         RC
# 4664     None      High - Code       None  ...     None        RC         RC
# 4665     None      High - Code       None  ...     None        RC         RC
# 4666     None      High - Code       None  ...     None        RC         RC
# 4667     None  Moderate - Code       None  ...     None        RC         RC
# 4668     None  Moderate - Code       None  ...     None        RC         RC
# 4669     None       Pre - Code       None  ...     None        W1         W1
# 4670     None       Pre - Code       None  ...     None        W1         W1
# 4671     None       Low - Code       None  ...     None        W2         W2
# 4672     None  Moderate - Code       None  ...     None        W2         W2
# 4673     None  Moderate - Code       None  ...     None        W1         W1
# 4674     None       Pre - Code       None  ...     None        RC         RC
# 4675     None       Pre - Code       None  ...     None        W1         W1
# 4676     None       Low - Code       None  ...     None        W2         W2
# 4677     None       Pre - Code       None  ...     None        W1         W1
# 4678     None  Moderate - Code       None  ...     None        RC         RC
#
#      tract_id year_built                               strctid           x  \
# 0        None       1968                    41007020933038031S -123.908997
# 1        None       1992                    41007022416079053S -123.905846
# 2        None       1974                    41007020933038014S -123.908997
# 3        None       1984                    41007020933038018S -123.908997
# 4        None       1964                    41007022789002002S -123.911827
# 5        None       2007                    41007022416079033S -123.905846
# 6        None       1941  3dcc3d59-dddf-4bc7-88cf-eacfe0b76ef0         NaN
# 7        None       1990  050589e0-041f-4ac6-83f8-420ac509cdde         NaN
# 8        None       1970                    41007021185022005S -123.910156
# 9        None       1975                    41007020933038016S -123.908997
# 10       None       1992                    41007022416079073S -123.905846
# 11       None       2006                    41007021520010001S -123.903778
# 12       None       1988                    41007022712044029S -123.915581
# 13       None       1959  d8ffb229-86e0-4907-97a5-84eb9ac248e6         NaN
# 14       None          1                    41007022465001001S -123.918518
# 15       None       1998                    41007022416079070S -123.905846
# 16       None       1974                    41007020933038020S -123.908997
# 17       None       1970                    41007021185022021S -123.910156
# 18       None       1968                    41007021185022010S -123.910156
# 19       None       1981                    41007021185022006S -123.910156
# 20       None       1975                    41007021185022014S -123.910156
# >Rosenheim, Nathanael, Roberto Guidotti, Paolo Gardoni & Walter Gillis Peacock. (2019). Integration of detailed household and housing unit characteristic data with critical infrastructure for post-hazard resilience modeling. Sustainable and Resilient Infrastructure. doi.org/10.1080/23789689.2019.1681821

# %%
# Seaside Housing Unit Inventory
housing_unit_inv_id = "5d543087b9219c0689b98234"
# load housing unit inventory as pandas dataframe
housing_unit_inv = Dataset.from_data_service(housing_unit_inv_id, data_service)
filename = housing_unit_inv.get_file_path('csv')
print("The IN-CORE Dataservice has saved the Housing Unit Inventory on your local machine: "+filename)
# Out:
# Dataset already exists locally. Reading from local cached zip.
# Unzipped folder found in the local cache. Reading from it...
# The IN-CORE Dataservice has saved the Housing Unit Inventory on your local machine: C:\Users\nathanael99\.incore\cache_data\5d543087b9219c0689b98234\IN-CORE_1bv6_SetupSeaside_FourInventories_2019-08-02_HUinventory\IN-CORE_1bv6_SetupSeaside_FourInventories_2019-08-02_HUinventory.csv

# %%
housing_unit_inv_df = pd.read_csv(filename, header="infer")
housing_unit_inv_df.head()
# Out:
#            blockid        blockidstr                  huid livetype  numprec  \
# 0  410079501001001  B410079501001001  B410079501001001H001        H        2
# 1  410079501001001  B410079501001001  B410079501001001H002        H        2
# 2  410079501001001  B410079501001001  B410079501001001H003        H        1
# 3  410079501001003  B410079501001003  B410079501001003H001        H        4
# 4  410079501001003  B410079501001003  B410079501001003H002        H        1
#
#    ownershp  race  hispan  vacancy  gqtype          bgid
# 0       1.0   1.0     0.0        0       0  410079501001
# 1       2.0   1.0     0.0        0       0  410079501001
# 2       1.0   1.0     0.0        0       0  410079501001
# 3       2.0   4.0     0.0        0       0  410079501001
# 4       2.0   1.0     0.0        0       0  410079501001

# %%
housing_unit_inv_df.columns
# Out:
# Index(['blockid', 'blockidstr', 'huid', 'livetype', 'numprec', 'ownershp',
#        'race', 'hispan', 'vacancy', 'gqtype', 'bgid'],
#       dtype='object')

# %% [markdown]
# ### Explore Housing Unit Characteristics
# The housing unit inventory includes characteristics based on the 2010 Decennial Census.

# %% [markdown]
# ### Race and Ethnicity
# The housing unit inventory includes variables for race and ethnicity.

# %%
housing_unit_inv_df['Race Ethnicity'] = "0 Vacant HU No Race Ethnicity Data"
housing_unit_inv_df['Race Ethnicity'].notes = "Identify Race and Ethnicity Housing Unit Characteristics."

housing_unit_inv_df.loc[(housing_unit_inv_df['race'] == 1) & 
                        (housing_unit_inv_df['hispan'] == 0),'Race Ethnicity'] = "1 White alone, Not Hispanic"
housing_unit_inv_df.loc[(housing_unit_inv_df['race'] == 2) & 
                        (housing_unit_inv_df['hispan'] == 0),'Race Ethnicity'] = "2 Black alone, Not Hispanic"
housing_unit_inv_df.loc[(housing_unit_inv_df['race'].isin([3,4,5,6,7])) & 
                        (housing_unit_inv_df['hispan'] == 0),'Race Ethnicity'] = "3 Other Race, Not Hispanic"
housing_unit_inv_df.loc[(housing_unit_inv_df['hispan'] == 1),'Race Ethnicity'] = "4 Any Race, Hispanic"
housing_unit_inv_df.loc[(housing_unit_inv_df['gqtype'] >= 1),'Race Ethnicity'] = "5 Group Quarters no Race Ethnicity Data"

housing_unit_inv_df['Tenure Status'] = "0 No Tenure Status"
housing_unit_inv_df.loc[(housing_unit_inv_df['ownershp'] == 1),'Tenure Status'] = "1 Owner Occupied"
housing_unit_inv_df.loc[(housing_unit_inv_df['ownershp'] == 2),'Tenure Status'] = "2 Renter Occupied"
housing_unit_inv_df['Tenure Status'].notes = "Identify Tenure Status Housing Unit Characteristics."

# %%
table = pd.pivot_table(housing_unit_inv_df, values='numprec', index=['Race Ethnicity'],
                                     margins = True, margins_name = 'Total',
                                     columns=['Tenure Status'], aggfunc=[np.sum]).rename(
    columns={'Total': 'Total Population', 'sum': ''})
table_title = "Table 1. Total Population by Race, Ethncity, and Tenure Status, Jefferson and Newton Counties, 2010."
varformat = {('','Total Population'): "{:,.0f}",
             ('','1 Owner Occupied'): "{:,.0f}",
             ('','2 Renter Occupied'): "{:,.0f}"}
table.style.set_caption(table_title).format(varformat)
# Out:
# <style  type="text/css" >
# </style><table id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6c" ><caption>Table 1. Total Population by Race, Ethncity, and Tenure Status, Jefferson and Newton Counties, 2010.</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4></th>    </tr>    <tr>        <th class="index_name level1" >Tenure Status</th>        <th class="col_heading level1 col0" >0 No Tenure Status</th>        <th class="col_heading level1 col1" >1 Owner Occupied</th>        <th class="col_heading level1 col2" >2 Renter Occupied</th>        <th class="col_heading level1 col3" >Total Population</th>    </tr>    <tr>        <th class="index_name level0" >Race Ethnicity</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6clevel0_row0" class="row_heading level0 row0" >0 Vacant HU No Race Ethnicity Data</th>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow0_col1" class="data row0 col1" >nan</td>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow0_col2" class="data row0 col2" >nan</td>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow0_col3" class="data row0 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6clevel0_row1" class="row_heading level0 row1" >1 White alone, Not Hispanic</th>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow1_col1" class="data row1 col1" >21,017</td>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow1_col2" class="data row1 col2" >11,027</td>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow1_col3" class="data row1 col3" >32,044</td>
#             </tr>
#             <tr>
#                         <th id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6clevel0_row2" class="row_heading level0 row2" >2 Black alone, Not Hispanic</th>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow2_col0" class="data row2 col0" >nan</td>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow2_col1" class="data row2 col1" >55</td>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow2_col2" class="data row2 col2" >48</td>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow2_col3" class="data row2 col3" >103</td>
#             </tr>
#             <tr>
#                         <th id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6clevel0_row3" class="row_heading level0 row3" >3 Other Race, Not Hispanic</th>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow3_col0" class="data row3 col0" >nan</td>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow3_col1" class="data row3 col1" >765</td>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow3_col2" class="data row3 col2" >786</td>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow3_col3" class="data row3 col3" >1,551</td>
#             </tr>
#             <tr>
#                         <th id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6clevel0_row4" class="row_heading level0 row4" >4 Any Race, Hispanic</th>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow4_col0" class="data row4 col0" >nan</td>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow4_col1" class="data row4 col1" >595</td>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow4_col2" class="data row4 col2" >1,645</td>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow4_col3" class="data row4 col3" >2,240</td>
#             </tr>
#             <tr>
#                         <th id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6clevel0_row5" class="row_heading level0 row5" >5 Group Quarters no Race Ethnicity Data</th>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow5_col0" class="data row5 col0" >956</td>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow5_col1" class="data row5 col1" >nan</td>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow5_col2" class="data row5 col2" >nan</td>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow5_col3" class="data row5 col3" >956</td>
#             </tr>
#             <tr>
#                         <th id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6clevel0_row6" class="row_heading level0 row6" >Total</th>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow6_col0" class="data row6 col0" >956</td>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow6_col1" class="data row6 col1" >22,432</td>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow6_col2" class="data row6 col2" >13,506</td>
#                         <td id="T_74f20028_88f7_11eb_97f7_34e12d5f5b6crow6_col3" class="data row6 col3" >36,894</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## 1a + 1b) Interdependent Community Description
#
# Explore building inventory and social systems. Specifically look at how the building inventory connects with the housing unit inventory using the housing unit allocation.
# The housing unit allocation method will provide detail demographic characteristics for the community allocated to each structure.
#
# To run the HUA Algorithm, three input datasets are required:
#
# 1. Housing Unit Inventory - Based on 2010 US Census Block Level Data
#
# 2. Address Point Inventory - A list of all possible residential/business address points in a community. Address points are the link between buildings and housing units.
#
# 3. Building Inventory - A list of all buildings within a community.

# %% [markdown]
# ### Set Up and Run Housing Unit Allocation

# %% [markdown]
# The bulding and housing unit inventories have already by loaded. The address point inventory is needed to link the population with the structures.

# %%
# Housing unit and Building Inventories have been loaded
# Galveston, TX Address point inventory
address_point_inv_id = "5d542fefb9219c0689b981fb"

# %%
from pyincore.analyses.housingunitallocation import HousingUnitAllocation

# Create housing allocation 
hua = HousingUnitAllocation(client)

# Load input dataset
hua.load_remote_input_dataset("housing_unit_inventory", housing_unit_inv_id)
hua.load_remote_input_dataset("address_point_inventory", address_point_inv_id)
#hua.load_remote_input_dataset("buildings", bldg_inv_id)
hua.set_input_dataset("buildings", building_inv)

# Specify the result name
result_name = "Seaside_HUA"

seed = 1238
iterations = 1

# Set analysis parameters
hua.set_parameter("result_name", result_name)
hua.set_parameter("seed", seed)
hua.set_parameter("iterations", iterations)
# Out:
# Dataset already exists locally. Reading from local cached zip.
# Unzipped folder found in the local cache. Reading from it...
# Dataset already exists locally. Reading from local cached zip.
# Unzipped folder found in the local cache. Reading from it...
# True

# %%
# Run Housing unit allocation analysis
hua.run_analysis()
# Out:
# True

# %% [markdown]
# ### Explore results from Housing Unit Allocation

# %%
# Retrieve result dataset
hua_result = hua.get_output_dataset("result")

# Convert dataset to Pandas DataFrame
hua_df = hua_result.get_dataframe_from_csv(low_memory=False)

# Display top 5 rows of output data
hua_df[['guid','numprec','ownershp','geometry','aphumerge']].head()
# Out:
#                                    guid  numprec  ownershp  \
# 0  e38d8575-7880-4a8c-b6d7-225ab1cf9264      2.0       1.0
# 1  af5771b4-4f42-4166-b772-78a3706fa8ac      1.0       1.0
# 2  37532fb5-5107-478b-ab2c-158eb001c68b      4.0       1.0
# 3  66d39314-1c68-4634-a82c-8fcb37f529ff      3.0       1.0
# 4  e519ec32-c5eb-422a-be3d-7ff4bb33f1e2      2.0       1.0
#
#                                        geometry aphumerge
# 0  POINT (-123.8960661064165 46.01272230816045)      both
# 1  POINT (-123.9034265041881 46.01749849919388)      both
# 2  POINT (-123.9034265041881 46.01749849919388)      both
# 3  POINT (-123.9002451964179 46.01352343272472)      both
# 4  POINT (-123.8989178756465 46.01225606771315)      both

# %%
hua_df.guid.describe()
# Out:
# count                                     6980
# unique                                    4679
# top       a698bf89-e06b-4d88-8116-81037737919b
# freq                                        66
# Name: guid, dtype: object

# %%
hua_df.huid.describe()
# Out:
# count                    21579
# unique                   21579
# top       B410079506002002H083
# freq                         1
# Name: huid, dtype: object

# %%
hua_df.columns
# Out:
# Index(['addrptid', 'FID_NEW', 'a_stories', 'appr_bldg', 'b_stories', 'bldg_id',
#        'broad_occ', 'bsmt_type', 'cont_val', 'dgn_lvl', 'dwell_unit',
#        'efacility', 'elev', 'gsq_foot', 'guid', 'major_occ', 'no_stories',
#        'nstra_cst', 'nstrd_cst', 'occ_detail', 'occ_typ2', 'occ_type',
#        'origin', 'parid', 'parid_card', 'period', 'repl_cst', 'rmv_improv',
#        'rmv_land', 'sq_foot', 'stat_class', 'str_cst', 'str_prob', 'str_typ2',
#        'strctid', 'struct_typ', 'tract_id', 'value_matc', 'year_built',
#        'blockid', 'huestimate', 'residential', 'x', 'y', 'randomap',
#        'randommergeorder', 'blockidstr', 'huid', 'livetype', 'numprec',
#        'ownershp', 'race', 'hispan', 'vacancy', 'gqtype', 'bgid', 'randomhu',
#        'aphumerge', 'geometry'],
#       dtype='object')

# %%
# keep observations where the housing unit characteristics have been allocated to a structure.
hua_df = hua_df.dropna(subset=['guid'])

# %%
hua_df.huid.describe()
# Out:
# count                     4741
# unique                    4741
# top       B410079509005047H003
# freq                         1
# Name: huid, dtype: object

# %%
hua_df['Race Ethnicity'] = "0 Vacant HU No Race Ethnicity Data"
hua_df['Race Ethnicity'].notes = "Identify Race and Ethnicity Housing Unit Characteristics."

hua_df.loc[(hua_df['race'] == 1) & 
                        (hua_df['hispan'] == 0),'Race Ethnicity'] = "1 White alone, Not Hispanic"
hua_df.loc[(hua_df['race'] == 2) & 
                        (hua_df['hispan'] == 0),'Race Ethnicity'] = "2 Black alone, Not Hispanic"
hua_df.loc[(hua_df['race'].isin([3,4,5,6,7])) & 
                        (hua_df['hispan'] == 0),'Race Ethnicity'] = "3 Other Race, Not Hispanic"
hua_df.loc[(hua_df['hispan'] == 1),'Race Ethnicity'] = "4 Any Race, Hispanic"
hua_df.loc[(hua_df['gqtype'] >= 1),'Race Ethnicity'] = "5 Group Quarters no Race Ethnicity Data"

hua_df['Tenure Status'] = "0 No Tenure Status"
hua_df.loc[(hua_df['ownershp'] == 1),'Tenure Status'] = "1 Owner Occupied"
hua_df.loc[(hua_df['ownershp'] == 2),'Tenure Status'] = "2 Renter Occupied"
hua_df['Tenure Status'].notes = "Identify Tenure Status Housing Unit Characteristics."

# %%
table = pd.pivot_table(hua_df, values='numprec', index=['Race Ethnicity'],
                                     margins = True, margins_name = 'Total',
                                     columns=['Tenure Status'], aggfunc=[np.sum]).rename(
    columns={'Total': 'Total Population', 'sum': ''})
table_title = "Table 1. Total Population by Race, Ethncity, and Tenure Status, Joplin, MO, 2010."
varformat = {('','Total Population'): "{:,.0f}",
             ('','0 No Tenure Status'): "{:,.0f}",
             ('','1 Owner Occupied'): "{:,.0f}",
             ('','2 Renter Occupied'): "{:,.0f}"}
table.style.set_caption(table_title).format(varformat)
# Out:
# <style  type="text/css" >
# </style><table id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6c" ><caption>Table 1. Total Population by Race, Ethncity, and Tenure Status, Joplin, MO, 2010.</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" colspan=4></th>    </tr>    <tr>        <th class="index_name level1" >Tenure Status</th>        <th class="col_heading level1 col0" >0 No Tenure Status</th>        <th class="col_heading level1 col1" >1 Owner Occupied</th>        <th class="col_heading level1 col2" >2 Renter Occupied</th>        <th class="col_heading level1 col3" >Total Population</th>    </tr>    <tr>        <th class="index_name level0" >Race Ethnicity</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6clevel0_row0" class="row_heading level0 row0" >0 Vacant HU No Race Ethnicity Data</th>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow0_col0" class="data row0 col0" >0</td>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow0_col1" class="data row0 col1" >nan</td>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow0_col2" class="data row0 col2" >nan</td>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow0_col3" class="data row0 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6clevel0_row1" class="row_heading level0 row1" >1 White alone, Not Hispanic</th>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow1_col0" class="data row1 col0" >nan</td>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow1_col1" class="data row1 col1" >2,631</td>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow1_col2" class="data row1 col2" >2,900</td>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow1_col3" class="data row1 col3" >5,531</td>
#             </tr>
#             <tr>
#                         <th id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6clevel0_row2" class="row_heading level0 row2" >2 Black alone, Not Hispanic</th>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow2_col0" class="data row2 col0" >nan</td>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow2_col1" class="data row2 col1" >7</td>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow2_col2" class="data row2 col2" >17</td>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow2_col3" class="data row2 col3" >24</td>
#             </tr>
#             <tr>
#                         <th id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6clevel0_row3" class="row_heading level0 row3" >3 Other Race, Not Hispanic</th>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow3_col0" class="data row3 col0" >nan</td>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow3_col1" class="data row3 col1" >136</td>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow3_col2" class="data row3 col2" >191</td>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow3_col3" class="data row3 col3" >327</td>
#             </tr>
#             <tr>
#                         <th id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6clevel0_row4" class="row_heading level0 row4" >4 Any Race, Hispanic</th>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow4_col0" class="data row4 col0" >nan</td>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow4_col1" class="data row4 col1" >187</td>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow4_col2" class="data row4 col2" >524</td>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow4_col3" class="data row4 col3" >711</td>
#             </tr>
#             <tr>
#                         <th id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6clevel0_row5" class="row_heading level0 row5" >5 Group Quarters no Race Ethnicity Data</th>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow5_col0" class="data row5 col0" >47</td>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow5_col1" class="data row5 col1" >nan</td>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow5_col2" class="data row5 col2" >nan</td>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow5_col3" class="data row5 col3" >47</td>
#             </tr>
#             <tr>
#                         <th id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6clevel0_row6" class="row_heading level0 row6" >Total</th>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow6_col0" class="data row6 col0" >47</td>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow6_col1" class="data row6 col1" >2,961</td>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow6_col2" class="data row6 col2" >3,632</td>
#                         <td id="T_7772c992_88f7_11eb_bc7e_34e12d5f5b6crow6_col3" class="data row6 col3" >6,640</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# #### Validate the Housing Unit Allocation has worked
# Notice that the population count totals for the community should match (pretty closely) data collected for the 2010 Decennial Census.
# This can be confirmed by going to data.census.gov
#
# Total Population by Race and Ethnicity:
# https://data.census.gov/cedsci/table?q=DECENNIALPL2010.H11&g=1600000US4165950&tid=DECENNIALSF12010.H11
#
# Differences in the housing unit allocation and the Census count may be due to differences between political boundaries and the building inventory. See Rosenheim et al 2019 for more details.
#
# The housing unit allocation, plus the building results will become the input for the social science models such as the population dislocatoin model.

# %%
# Use shapely.wkt loads to convert WKT to GeoSeries
from shapely.geometry import Point
# Geodata frame requires geometry and CRS to be set
hua_gdf = gpd.GeoDataFrame(
    hua_df,
    crs={'init': 'epsg:4326'},
    geometry=[Point(xy) for xy in zip(hua_df['x'], hua_df['y'])])
hua_gdf[['guid','x','y','ownershp','geometry']].head(6)
# Out:
#                                    guid           x          y  ownershp  \
# 0  e38d8575-7880-4a8c-b6d7-225ab1cf9264 -123.896065  46.012722       1.0
# 1  af5771b4-4f42-4166-b772-78a3706fa8ac -123.903427  46.017498       1.0
# 2  37532fb5-5107-478b-ab2c-158eb001c68b -123.903427  46.017498       1.0
# 3  66d39314-1c68-4634-a82c-8fcb37f529ff -123.900246  46.013523       1.0
# 4  e519ec32-c5eb-422a-be3d-7ff4bb33f1e2 -123.898918  46.012257       1.0
# 5  0edcff97-8fa1-4558-b80e-610abe7b9f17 -123.898552  46.012253       1.0
#
#                       geometry
# 0  POINT (-123.89606 46.01272)
# 1  POINT (-123.90343 46.01750)
# 2  POINT (-123.90343 46.01750)
# 3  POINT (-123.90025 46.01352)
# 4  POINT (-123.89892 46.01226)
# 5  POINT (-123.89855 46.01225)

# %%
# visualize population
gdf = hua_gdf
map = viz.plot_gdf_map(gdf,column='ownershp')
map

# %%
# visualize population by race and tenure status
minority_renters_gdf = hua_gdf.loc[(hua_gdf.race != 1) &
                                    (hua_gdf['Tenure Status'] == '2 Renter Occupied')]
map = viz.plot_gdf_map(minority_renters_gdf,column='race')
map

# %%
# What location should the map be centered on?
center_x = hua_gdf.bounds.minx.mean()
center_y = hua_gdf.bounds.miny.mean()
center_x, center_y
# Out:
# (-123.92208882309136, 45.993245623631466)

# %%
# https://ipyleaflet.readthedocs.io/en/latest/api_reference/heatmap.html
import ipyleaflet as ipylft
from ipyleaflet import Map, Heatmap

# %%
print("ipyleaflet Version ",ipylft.__version__)
# Out:
# ipyleaflet Version  0.13.6

# %%
popdata = minority_renters_gdf[['y','x','numprec']].values.tolist()

# %%
from ipyleaflet import Map, Heatmap, LayersControl

map = Map(center=[center_y,center_x], zoom=13)

minority_renters_gdf = Heatmap(
    locations = popdata,
    radius = 10, 
    max_val = 1000, 
    blur = 10, 
    gradient={0.2: 'yellow', 0.5: 'orange', 1.0: 'red'},
    name = 'Minority Renters',
)

map.add_layer(minority_renters_gdf);
control = LayersControl(position='topright')
map.add_control(control)
map
# Out:
# Map(center=[45.993245623631466, -123.92208882309136], controls=(ZoomControl(options=['position', 'zoom_in_text…
